# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/MyDrive/Colab\ Notebooks/Object\ detection/object-detection-notebooks
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Colab Notebooks/Object detection/object-detection-notebooks

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import pickle
import cv2
import os
# %matplotlib inline

# %%
# define the base path to the input dataset and then use it to derive
# the path to the input images and annotation CSV files
BASE_PATH = "dataset2"
IMAGES_PATH = os.path.sep.join([BASE_PATH, "images"])
ANNOTS_PATH = os.path.sep.join([BASE_PATH, "annotations"])

# %%
data = []
labels = []
bboxes = []
imagePaths = []
csvPaths = []

for (rootDir, dirNames, filenames) in os.walk(ANNOTS_PATH):
    # loop over the filenames in the current directory
    for filename in filenames:
        # determine the file extension of the current file
        ext = filename[filename.rfind("."):].lower()

        # check to see if the file is an image and should be processed
        if ext.endswith(".csv"):
            # construct the path to the image and yield it
            csvPath = os.path.join(rootDir, filename)
            csvPaths.append(csvPath)

csvPaths
# Out:
# ['dataset2/annotations/airplane.csv',
#  'dataset2/annotations/face.csv',
#  'dataset2/annotations/motorcycle.csv']

# %%
# loop over all CSV files in the annotations directory
for csvPath in csvPaths:
    # load the contents of the current CSV annotations file
    rows = open(csvPath).read().strip().split("\n")

    # loop over the rows
    for row in rows:
        # break the row into the filename, bounding box coordinates,
        # and class label
        row = row.split(",")
        (filename, startX, startY, endX, endY, label) = row

        # derive the path to the input image, load the image (in
        # OpenCV format), and grab its dimensions
        imagePath = os.path.sep.join([IMAGES_PATH, label, filename])
        image = cv2.imread(imagePath)
        (h, w) = image.shape[:2]

        # scale the bounding box coordinates relative to the spatial
        # dimensions of the input image
        startX = float(startX) / w
        startY = float(startY) / h
        endX = float(endX) / w
        endY = float(endY) / h

        # load the image and preprocess it
        image = load_img(imagePath, target_size=(224, 224))
        image = img_to_array(image)

        # update our list of data, class labels, bounding boxes, and
        # image paths
        data.append(image)
        labels.append(label)
        bboxes.append((startX, startY, endX, endY))
        imagePaths.append(imagePath)

# %%
# convert the data, class labels, bounding boxes, and image paths to
# NumPy arrays, scaling the input pixel intensities from the range
# [0, 255] to [0, 1]
data = np.array(data, dtype="float32") / 255.0
labels = np.array(labels)
bboxes = np.array(bboxes, dtype="float32")
imagePaths = np.array(imagePaths)

# %%
# perform one-hot encoding on the labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)

# %%
# partition the data into training and testing splits using 80% of
# the data for training and the remaining 20% for testing
split = train_test_split(data, labels, bboxes, imagePaths, test_size=0.20, random_state=42)
# unpack the data split
(trainImages, testImages) = split[:2]
(trainLabels, testLabels) = split[2:4]
(trainBBoxes, testBBoxes) = split[4:6]
(trainPaths, testPaths) = split[6:]

# %%
# load the VGG16 network, ensuring the head FC layers are left off
vgg = VGG16(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))
# freeze all VGG layers so they will *not* be updated during the
# training process
vgg.trainable = False
# flatten the max-pooling output of VGG
flatten = vgg.output
flatten = Flatten()(flatten)

# construct a fully-connected layer header to output the predicted
# bounding box coordinates
bboxHead = Dense(128, activation="relu")(flatten)
bboxHead = Dense(64, activation="relu")(bboxHead)
bboxHead = Dense(32, activation="relu")(bboxHead)
bboxHead = Dense(4, activation="sigmoid", name="bounding_box")(bboxHead)

# construct a second fully-connected layer head, this one to predict
# the class label
softmaxHead = Dense(512, activation="relu")(flatten)
softmaxHead = Dropout(0.5)(softmaxHead)
softmaxHead = Dense(512, activation="relu")(softmaxHead)
softmaxHead = Dropout(0.5)(softmaxHead)
softmaxHead = Dense(len(lb.classes_), activation="softmax", name="class_label")(softmaxHead)

# put together our model which accept an input image and then output
# bounding box coordinates and a class label
model = Model(inputs=vgg.input, outputs=(bboxHead, softmaxHead))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step

# %%
# define a dictionary to set the loss methods -- categorical
# cross-entropy for the class label head and mean absolute error
# for the bounding box head
losses = {
    "class_label": "categorical_crossentropy",
    "bounding_box": "mean_squared_error",
}

# define a dictionary that specifies the weights per loss (both the
# class label and bounding box outputs will receive equal weight)
lossWeights = {
    "class_label": 1.0,
    "bounding_box": 1.0
}
model.compile(loss=losses, optimizer=Adam(learning_rate=1e-4), metrics=["accuracy"], loss_weights=lossWeights)

# %%
# construct a dictionary for our target training outputs
trainTargets = {
    "class_label": trainLabels,
    "bounding_box": trainBBoxes
}

# construct a second dictionary, this one for our target testing
# outputs
testTargets = {
    "class_label": testLabels,
    "bounding_box": testBBoxes
}

# train the network for bounding box regression and class label
# prediction
H = model.fit(
    trainImages, trainTargets,
    validation_data=(testImages, testTargets),
    batch_size=32,
    epochs=20,
    verbose=1)
# Out:
# Epoch 1/20
# 51/51 [==============================] - 53s 365ms/step - loss: 0.1883 - bounding_box_loss: 0.0106 - class_label_loss: 0.1777 - bounding_box_accuracy: 0.7245 - class_label_accuracy: 0.9305 - val_loss: 0.0071 - val_bounding_box_loss: 0.0014 - val_class_label_loss: 0.0056 - val_bounding_box_accuracy: 0.8329 - val_class_label_accuracy: 0.9975
# Epoch 2/20
# 51/51 [==============================] - 9s 184ms/step - loss: 0.0125 - bounding_box_loss: 0.0013 - class_label_loss: 0.0112 - bounding_box_accuracy: 0.8487 - class_label_accuracy: 0.9969 - val_loss: 0.0021 - val_bounding_box_loss: 0.0010 - val_class_label_loss: 0.0010 - val_bounding_box_accuracy: 0.8624 - val_class_label_accuracy: 1.0000
# Epoch 3/20
# 51/51 [==============================] - 9s 186ms/step - loss: 0.0072 - bounding_box_loss: 8.8797e-04 - class_label_loss: 0.0063 - bounding_box_accuracy: 0.8604 - class_label_accuracy: 0.9988 - val_loss: 0.0017 - val_bounding_box_loss: 9.6458e-04 - val_class_label_loss: 7.7653e-04 - val_bounding_box_accuracy: 0.8550 - val_class_label_accuracy: 1.0000
# Epoch 4/20
# 51/51 [==============================] - 10s 189ms/step - loss: 0.0074 - bounding_box_loss: 7.0926e-04 - class_label_loss: 0.0067 - bounding_box_accuracy: 0.8739 - class_label_accuracy: 0.9975 - val_loss: 0.0017 - val_bounding_box_loss: 9.1002e-04 - val_class_label_loss: 7.8719e-04 - val_bounding_box_accuracy: 0.8477 - val_class_label_accuracy: 1.0000
# Epoch 5/20
# 51/51 [==============================] - 10s 189ms/step - loss: 0.0022 - bounding_box_loss: 5.8232e-04 - class_label_loss: 0.0017 - bounding_box_accuracy: 0.8813 - class_label_accuracy: 1.0000 - val_loss: 0.0013 - val_bounding_box_loss: 8.6171e-04 - val_class_label_loss: 4.1423e-04 - val_bounding_box_accuracy: 0.8501 - val_class_label_accuracy: 1.0000
# Epoch 6/20
# 51/51 [==============================] - 10s 189ms/step - loss: 0.0014 - bounding_box_loss: 4.7757e-04 - class_label_loss: 9.5435e-04 - bounding_box_accuracy: 0.9004 - class_label_accuracy: 1.0000 - val_loss: 0.0011 - val_bounding_box_loss: 8.1726e-04 - val_class_label_loss: 2.9845e-04 - val_bounding_box_accuracy: 0.8821 - val_class_label_accuracy: 1.0000
# Epoch 7/20
# 51/51 [==============================] - 10s 189ms/step - loss: 0.0011 - bounding_box_loss: 4.0382e-04 - class_label_loss: 6.7262e-04 - bounding_box_accuracy: 0.9028 - class_label_accuracy: 1.0000 - val_loss: 0.0011 - val_bounding_box_loss: 7.9708e-04 - val_class_label_loss: 2.8812e-04 - val_bounding_box_accuracy: 0.8845 - val_class_label_accuracy: 1.0000
# Epoch 8/20
# 51/51 [==============================] - 10s 191ms/step - loss: 9.2067e-04 - bounding_box_loss: 3.4198e-04 - class_label_loss: 5.7869e-04 - bounding_box_accuracy: 0.9041 - class_label_accuracy: 1.0000 - val_loss: 9.9859e-04 - val_bounding_box_loss: 8.1093e-04 - val_class_label_loss: 1.8766e-04 - val_bounding_box_accuracy: 0.8821 - val_class_label_accuracy: 1.0000
# Epoch 9/20
# 51/51 [==============================] - 10s 190ms/step - loss: 9.0693e-04 - bounding_box_loss: 3.0391e-04 - class_label_loss: 6.0302e-04 - bounding_box_accuracy: 0.9176 - class_label_accuracy: 1.0000 - val_loss: 9.3906e-04 - val_bounding_box_loss: 7.7232e-04 - val_class_label_loss: 1.6674e-04 - val_bounding_box_accuracy: 0.8796 - val_class_label_accuracy: 1.0000
# Epoch 10/20
# 51/51 [==============================] - 10s 190ms/step - loss: 6.4081e-04 - bounding_box_loss: 2.6897e-04 - class_label_loss: 3.7184e-04 - bounding_box_accuracy: 0.9188 - class_label_accuracy: 1.0000 - val_loss: 9.5500e-04 - val_bounding_box_loss: 7.9395e-04 - val_class_label_loss: 1.6105e-04 - val_bounding_box_accuracy: 0.8968 - val_class_label_accuracy: 1.0000
# Epoch 11/20
# 51/51 [==============================] - 10s 191ms/step - loss: 5.9702e-04 - bounding_box_loss: 2.3400e-04 - class_label_loss: 3.6302e-04 - bounding_box_accuracy: 0.9231 - class_label_accuracy: 1.0000 - val_loss: 9.0378e-04 - val_bounding_box_loss: 7.6787e-04 - val_class_label_loss: 1.3592e-04 - val_bounding_box_accuracy: 0.8722 - val_class_label_accuracy: 1.0000
# Epoch 12/20
# 51/51 [==============================] - 10s 192ms/step - loss: 4.0277e-04 - bounding_box_loss: 2.0784e-04 - class_label_loss: 1.9493e-04 - bounding_box_accuracy: 0.9213 - class_label_accuracy: 1.0000 - val_loss: 9.3675e-04 - val_bounding_box_loss: 7.6575e-04 - val_class_label_loss: 1.7099e-04 - val_bounding_box_accuracy: 0.8673 - val_class_label_accuracy: 1.0000
# Epoch 13/20
# 51/51 [==============================] - 10s 192ms/step - loss: 5.6463e-04 - bounding_box_loss: 1.8578e-04 - class_label_loss: 3.7885e-04 - bounding_box_accuracy: 0.9293 - class_label_accuracy: 1.0000 - val_loss: 8.5589e-04 - val_bounding_box_loss: 7.4716e-04 - val_class_label_loss: 1.0873e-04 - val_bounding_box_accuracy: 0.8894 - val_class_label_accuracy: 1.0000
# Epoch 14/20
# 51/51 [==============================] - 10s 193ms/step - loss: 7.1270e-04 - bounding_box_loss: 1.7816e-04 - class_label_loss: 5.3454e-04 - bounding_box_accuracy: 0.9323 - class_label_accuracy: 1.0000 - val_loss: 9.0155e-04 - val_bounding_box_loss: 7.5341e-04 - val_class_label_loss: 1.4814e-04 - val_bounding_box_accuracy: 0.8747 - val_class_label_accuracy: 1.0000
# Epoch 15/20
# 51/51 [==============================] - 10s 194ms/step - loss: 6.8895e-04 - bounding_box_loss: 1.6456e-04 - class_label_loss: 5.2438e-04 - bounding_box_accuracy: 0.9336 - class_label_accuracy: 1.0000 - val_loss: 0.0010 - val_bounding_box_loss: 7.5276e-04 - val_class_label_loss: 2.7089e-04 - val_bounding_box_accuracy: 0.8722 - val_class_label_accuracy: 1.0000
# Epoch 16/20
# 51/51 [==============================] - 10s 194ms/step - loss: 4.9691e-04 - bounding_box_loss: 1.6552e-04 - class_label_loss: 3.3139e-04 - bounding_box_accuracy: 0.9410 - class_label_accuracy: 1.0000 - val_loss: 8.5702e-04 - val_bounding_box_loss: 7.4067e-04 - val_class_label_loss: 1.1634e-04 - val_bounding_box_accuracy: 0.8673 - val_class_label_accuracy: 1.0000
# Epoch 17/20
# 51/51 [==============================] - 10s 193ms/step - loss: 2.9577e-04 - bounding_box_loss: 1.4608e-04 - class_label_loss: 1.4968e-04 - bounding_box_accuracy: 0.9471 - class_label_accuracy: 1.0000 - val_loss: 8.3011e-04 - val_bounding_box_loss: 7.4161e-04 - val_class_label_loss: 8.8500e-05 - val_bounding_box_accuracy: 0.8649 - val_class_label_accuracy: 1.0000
# Epoch 18/20
# 51/51 [==============================] - 10s 195ms/step - loss: 2.4088e-04 - bounding_box_loss: 1.4158e-04 - class_label_loss: 9.9303e-05 - bounding_box_accuracy: 0.9428 - class_label_accuracy: 1.0000 - val_loss: 8.1249e-04 - val_bounding_box_loss: 7.4079e-04 - val_class_label_loss: 7.1700e-05 - val_bounding_box_accuracy: 0.8673 - val_class_label_accuracy: 1.0000
# Epoch 19/20
# 51/51 [==============================] - 10s 194ms/step - loss: 3.6208e-04 - bounding_box_loss: 1.4282e-04 - class_label_loss: 2.1926e-04 - bounding_box_accuracy: 0.9490 - class_label_accuracy: 1.0000 - val_loss: 7.8805e-04 - val_bounding_box_loss: 7.3251e-04 - val_class_label_loss: 5.5539e-05 - val_bounding_box_accuracy: 0.8649 - val_class_label_accuracy: 1.0000
# Epoch 20/20
# 51/51 [==============================] - 10s 195ms/step - loss: 2.4533e-04 - bounding_box_loss: 1.3405e-04 - class_label_loss: 1.1128e-04 - bounding_box_accuracy: 0.9502 - class_label_accuracy: 1.0000 - val_loss: 8.0361e-04 - val_bounding_box_loss: 7.5214e-04 - val_class_label_loss: 5.1477e-05 - val_bounding_box_accuracy: 0.8845 - val_class_label_accuracy: 1.0000

# %%
model.save('classification+localization.h5', save_format="h5")
with open('lb3.pickle', "wb") as f:
    f.write(pickle.dumps(lb))

# %%
# plot the total loss, label loss, and bounding box loss
lossNames = ["loss", "class_label_loss", "bounding_box_loss"]
N = np.arange(0, H.params['epochs'])
plt.style.use("ggplot")
(fig, ax) = plt.subplots(3, 1, figsize=(13, 13))

# loop over the loss names
for (i, l) in enumerate(lossNames):
    # plot the loss for both the training and validation data
    title = "Loss for {}".format(l) if l != "loss" else "Total loss"
    ax[i].set_title(title)
    ax[i].set_xlabel("Epoch #")
    ax[i].set_ylabel("Loss")
    ax[i].plot(N, H.history[l], label=l)
    ax[i].plot(N, H.history["val_" + l], label="val_" + l)
    ax[i].legend()

# save the losses figure and create a new figure for the accuracies
plt.tight_layout()

# create a new figure for the accuracies
plt.style.use("ggplot")
plt.figure()
plt.plot(N, H.history["class_label_accuracy"], label="class_label_train_acc")
plt.plot(N, H.history["val_class_label_accuracy"], label="val_class_label_acc")
plt.title("Class Label Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend(loc="lower left")

# %% [markdown]
# Source:
#
# https://www.pyimagesearch.com/2020/10/12/multi-class-object-detection-and-bounding-box-regression-with-keras-tensorflow-and-deep-learning/
